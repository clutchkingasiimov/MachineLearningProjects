# %% [markdown]
# # Feature Engineering Notebook

# %%
import pandas as pd
import sklearn as sk 
import rpy2 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np 
import pandas_datareader as web
import datetime
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

# %%
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv('/home/sauraj/spy.csv')

# %%
df['20-DayEMA'] = df['Adj Close'].rolling(window=20).mean()

# %% [markdown]
# # Dummy dataset for prototyping data labelling before implementing in on the whole dataset

# %%
df_dummy = df[0:200]
df_dummy

df_dummy
# Out:
#            Date        High         Low        Open       Close     Volume  \
# 0    2018-12-07  271.220001  262.630005  269.459991  263.570007  160907800
# 1    2018-12-06  269.970001  262.440002  265.920013  269.839996  204185400
# 2    2018-12-04  278.850006  269.899994  278.369995  270.250000  177986000
# 3    2018-12-03  280.399994  277.510010  280.279999  279.299988  103176300
# 4    2018-11-30  276.279999  273.450012  273.809998  275.649994   98204200
# 5    2018-11-29  275.549988  272.429993  273.709991  273.980011   82346400
# 6    2018-11-28  274.579987  268.329987  269.600006  274.579987  127629600
# 7    2018-11-27  268.399994  265.660004  266.339996  268.399994   75502400
# 8    2018-11-26  267.750000  265.339996  265.779999  267.500000   79843900
# 9    2018-11-23  264.820007  263.070007  263.179993  263.250000   42807900
# 10   2018-11-21  267.149994  265.010010  265.859985  265.019989   75563700
# 11   2018-11-20  267.000000  263.149994  265.359985  264.119995  136021300
# 12   2018-11-19  273.380005  268.070007  273.049988  269.100006  103061700
# 13   2018-11-16  274.750000  271.209991  271.790009  273.730011  126668000
# 14   2018-11-15  273.540009  267.010010  268.779999  273.019989  135101400
# 15   2018-11-14  274.609985  268.450012  274.160004  270.200012  125335900
# 16   2018-11-13  275.329987  271.250000  273.089996  272.059998   98176600
# 17   2018-11-12  277.459991  271.989990  277.190002  272.570007   99673600
# 18   2018-11-09  279.239990  276.179993  279.029999  277.760010   98812600
# 19   2018-11-08  281.220001  279.220001  280.109985  280.500000   65584900
# 20   2018-11-07  281.100006  277.079987  277.559998  281.010010  102752100
# 21   2018-11-06  275.299988  273.250000  273.320007  275.119995   60085900
# 22   2018-11-05  274.010010  271.350006  272.440002  273.390015   65622500
# 23   2018-11-02  275.230011  269.589996  274.750000  271.890015  122634100
# 24   2018-11-01  273.730011  270.380005  271.600006  273.510010   99495000
# 25   2018-10-31  273.230011  270.119995  270.649994  270.630005  128296300
# 26   2018-10-30  268.119995  263.119995  263.670013  267.769989  157116000
# 27   2018-10-29  270.250000  259.850006  268.799988  263.859985  160749100
# 28   2018-10-26  271.000000  262.290009  265.920013  265.329987  201574600
# 29   2018-10-25  271.809998  266.230011  267.380005  270.079987  138061500
# ..          ...         ...         ...         ...         ...        ...
# 170  2018-04-06  265.109985  258.000000  263.420013  259.720001  179521200
# 171  2018-04-05  266.640015  264.320007  265.549988  265.640015   82652600
# 8                Up          Down
# 9                Up            Up
# 10               Up            Up
# 11         Reversal          Down
# 12         Reversal          Down
# 13             Down          Down
# 14             Down          Down
# 15             Down            Up
# 16             Down          Down
# 17             Down            Up
# 18             Down          Down
# 19             Down          Down
# 20         Reversal          Down
# 21         Reversal            Up
# 22         Reversal          Down
# 23         Reversal          Down
# 24         Reversal            Up
# 25         Reversal          Down
# 26               Up            Up
# 27               Up            Up
# 28               Up            Up
# 29               Up          Down
# ..              ...           ...
# 170        Reversal            Up
# 171        Reversal          Down
# 172        Reversal          Down
# 173              Up            Up
# 174              Up            Up
# 175              Up            Up
# 176              Up          Down
# 177              Up            Up
# 178              Up            Up
# 179              Up            Up
# 180        Reversal          Down
# 181        Reversal          Down
# 182            Down          Down
# 183            Down          Down
# 184            Down          Down
# 185            Down            Up
# 186            Down            Up
# 187            Down          Down
# 188            Down          Down
# 189        Reversal            Up
# 190        Reversal          Down
# 191        Reversal            Up
# 192        Reversal            Up
# 193              Up            Up
# 194              Up          Down
# 195              Up            Up
# 196        Reversal            Up
# 197              Up          Down
# 198            Down          Down
# 199            Down          Down
#
# [200 rows x 20 columns]

# %%
df_dummy['CCI-pct%'] = df_dummy['CCI'].pct_change() * 100

# %%
df_dummy['AdjClose-pct%'] = df_dummy['Adj Close'].pct_change() * 100

# %%
df_dummy['Volume-pct%'] = df_dummy['Volume'].pct_change() * 100

# %%
for i in range(1, 200):
    if (df_dummy['MACD'][i] > df_dummy['MACD_Signal'][i]) & (((df_dummy['SlowD'][i] > 80) | (df_dummy['SlowK'][i] > 80))) or (((df_dummy['SlowD'][i] > 80) & (df_dummy['SlowK'][i] > 80))):

        df_dummy['Trend'][i] = 'Bullish'

    elif (df_dummy['MACD'][i] < df_dummy['MACD_Signal'][i]) & (((df_dummy['SlowD'][i] < 20) | (df_dummy['SlowK'][i] < 20))) or (((df_dummy['SlowD'][i] < 20) & (df_dummy['SlowK'][i] < 20))):

        df_dummy['Trend'][i] = 'Bearish'
    
    #elif(df_dummy['CCI-pct%'][i] < -100):

#        df_dummy['Trend'][i] = 'Reversal'
        
 #   else:
  #      df_dummy['Trend'][i] = 'Reversal'
    #elif(df_dummy['5-DayEMA'][i] < df_dummy['20-DayEMA'][i]) | (df_dummy['MACD'][i] > df_dummy['MACD_Signal'][i]):
        #df_dummy['Trend'] = 'Reversal'
# Out:
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
(((df_dummy['SlowD'][198] > 80) | (df_dummy['SlowK'][198] > 80))) or (((df_dummy['SlowD'][198] > 80) & (df_dummy['SlowK'][198] > 80)))
# Out:
# True

# %%
(df_dummy['SlowD'][i] < df_dummy['SlowD'][i-1]) and (df_dummy['SlowK'][i] < df_dummy['SlowK'][i-1]) <= 80
# Out:
# True

# %%
for i in range(1, 200):
    if (df_dummy['SlowK'][i] < df_dummy['SlowD'][i-1]) and (df_dummy['SlowK'][i] < df_dummy['SlowK'][i-1]) and ((df_dummy['SlowD'][i] and df_dummy['SlowK'][i] < 80)):
        df_dummy['StochasticTrend'][i] = 'Up'
    elif (df_dummy['SlowD'][i] > df_dummy['SlowD'][i-1]) and (df_dummy['SlowK'][i] > df_dummy['SlowK'][i-1]) and ((df_dummy['SlowD'][i] and df_dummy['SlowK'][i] < 80)):
        df_dummy['StochasticTrend'][i] = 'Down'
# Out:
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # Feature Engineering
#
# The goal is to first create new features out of the indicators and then use them to create the target label **Market Trend** and label each row according to the pre-requisite conditions

# %% [markdown]
# ### Stochastic Oscilator

# %%
for i in range(1, 200):
    if (df_dummy['SlowD'][i] and df_dummy['SlowK'][i] > df_dummy['SlowD'][i-1] and df_dummy['SlowK'][i-1]):
        df_dummy['StochasticTrend'][i] = 'Up'
    if (df_dummy['SlowD'][i] and df_dummy['SlowK'][i] < df_dummy['SlowD'][i-1] and df_dummy['SlowK'][i-1]):
        df_dummy['StochasticTrend'][i] = 'Down'
# Out:
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for i in range(1, 200):
    if (df_dummy['SlowK'][i] and df_dummy['SlowD'][i] > 80) or (df_dummy['SlowD'][i] or df_dummy['SlowK'][i] > 80) == True:
        df_dummy['StochasticTrend'][i] = 'Reversal'
    if (df_dummy['SlowK'][i] and df_dummy['SlowD'][i] < 20) or (df_dummy['SlowD'][i] or df_dummy['SlowK'][i] < 20) == True:
        df_dummy['StochasticTrend'][i] = 'Reversal'
# Out:
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for i in range(1, 200):
    if (df_dummy['SlowD'][i] and df_dummy['SlowK'][i] > 80) and (df_dummy['SlowD'][i] or df_dummy['SlowK'][i] > 80):
        df_dummy['StochasticTrend'][i] = 'Reversal'
    if (df_dummy['SlowD'][i] and df_dummy['SlowK'][i] < 20) and (df_dummy['SlowD'][i] or df_dummy['SlowK'][i] < 20):
        df_dummy['StochasticTrend'][i] = 'Reversal'
# Out:
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### AdjClose Trend

# %%
#AdjClose Price trend feature 
df_dummy['AdjCloseTrend'] = ''

# %%
#Feature filling ^
for i in range(1, 200):
    if df_dummy['Adj Close'][i] > df_dummy['Adj Close'][i-1]:
        df_dummy['AdjCloseTrend'][i] = 'Up'
    if df_dummy['Adj Close'][i] < df_dummy['Adj Close'][i-1]:
        df_dummy['AdjCloseTrend'][i] = 'Down'
# Out:
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### On BalanceVolume (OBV) Trend

# %%
#df_dummy['OBVTrend'] = ''

for i in range(1, 200):
    if df_dummy['OBV'][i] > df_dummy['OBV'][i-1]:
        df_dummy['OBVTrend'][i] = 'Up'
    if df_dummy['OBV'][i] < df_dummy['OBV'][i-1]:
        df_dummy['OBVTrend'][i] = 'Down'
# Out:
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### MACD Trend

# %%
#df_dummy['MACDTrend'] = ''

for i in range(1, 200):
    if (df_dummy['MACD'][i] > df_dummy['MACD'][i-1]) and (df_dummy['MACD_Signal'][i] > df_dummy['MACD_Signal'][i-1]):
        df_dummy['MACDTrend'][i] = 'Up'
        
    if (df_dummy['MACD'][i] < df_dummy['MACD'][i-1]) and (df_dummy['MACD_Signal'][i] < df_dummy['MACD_Signal'][i-1]):
        df_dummy['MACDTrend'][i] = 'Down'
    else:
        df_dummy['MACDTrend'][i] = 'Reversal'
# Out:
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### CCI Trend

# %%
#df_dummy['CCITrend'] = ''

for i in range(1, 200):
    if df_dummy['CCI'][i] > df_dummy['CCI'][i-1]:
        df_dummy['CCITrend'][i] = 'Up'
    if df_dummy['CCI'][i] < df_dummy['CCI'][i-1]:
        df_dummy['CCITrend'][i] = 'Down'
# Out:
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for i in range(1, 200):
    if df_dummy['CCI'][i] > 100 or df_dummy['CCI'][i] < -100:
        df_dummy['CCITrend'][i] = 'Reversal'
# Out:
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # How does the data look after feature engineering done above?

# %%
df_dummy.head(20)
#Drop RSI feature
#Use SPY's beta
# Out:
#           Date        High         Low        Open       Close     Volume  \
# 0   2018-02-23  274.709991  271.250000  271.790009  274.709991   92766400
# 1   2018-02-26  278.010010  275.260010  275.929993  277.899994   86491400
# 2   2018-02-27  278.920013  274.359985  278.109985  274.429993   99099200
# 3   2018-02-28  276.190002  271.290009  275.679993  271.649994  121907800
# 4   2018-03-01  273.170013  266.000000  271.410004  267.700012  176855100
# 5   2018-03-02  269.720001  264.820007  265.799988  269.079987  139083200
# 6   2018-03-05  272.890015  267.609985  267.730011  272.190002   97307400
# 7   2018-03-06  273.390015  271.179993  273.299988  272.880005   79213200
# 8   2018-03-07  273.179993  270.200012  270.420013  272.779999   87063500
# 9   2018-03-08  274.239990  272.420013  273.549988  274.100006   66901200
# 10  2018-03-09  278.869995  275.339996  275.700012  278.869995  113625300
# 11  2018-03-12  279.910004  278.079987  279.200012  278.519989   71924800
# 12  2018-03-13  280.410004  276.029999  279.839996  276.720001   91968900
# 13  2018-03-14  278.019989  274.670013  277.809998  275.299988  105895100
# 14  2018-03-15  276.609985  274.429993  275.880005  275.000000   83433000
# 15  2018-03-16  275.390015  274.140015  274.500000  274.200012  100343700
# 16  2018-03-19  274.399994  268.619995  273.350006  270.489990  109208400
# 17  2018-03-20  271.670013  270.179993  270.940002  270.950012   59757300
# 18  2018-03-21  273.269989  270.190002  270.899994  270.429993   78709600
# 19  2018-03-22  268.869995  263.359985  267.910004  263.670013  148785900
#
# 0
# 1         Reversal            Up       Up        Up        Up
# 2         Reversal          Down     Down        Up      Down
# 3         Reversal          Down     Down  Reversal      Down
# 4             Down          Down     Down  Reversal      Down
# 5             Down            Up       Up      Down      Down
# 6             Down            Up       Up        Up        Up
# 7             Down            Up       Up        Up        Up
# 8               Up          Down     Down        Up      Down
# 9               Up            Up       Up        Up        Up
# 10              Up            Up       Up        Up  Reversal
# 11        Reversal          Down     Down        Up  Reversal    Reversal
# 12        Reversal          Down     Down        Up  Reversal    Reversal
# 13            Down          Down     Down  Reversal      Down
# 14            Down          Down     Down  Reversal      Down
# 15            Down            Up     Down  Reversal      Down
# 16            Down          Down     Down      Down      Down
# 17            Down            Up       Up      Down      Down
# 18            Down          Down     Down      Down        Up
# 19            Down          Down     Down      Down  Reversal

# %% [markdown]
# # Creating the target feature: Market Trend
#
# * Condition for Reversal = Both "StochasticTrend" and "CCITrend" need to be "Reversal"
# * Condition for Bull/Bear = OBVTrend and AdjCloseTrend both need to be "Up" or "Down" to label them Bullish or Bearish

# %%
df_dummy['MarketTrend'] = ''

for i in range(1, 200):
    if (df_dummy['StochasticTrend'][i] == 'Reversal') & (df_dummy['CCITrend'][i] == 'Reversal'):
        df_dummy['MarketTrend'][i] = 'Reversal'
# Out:
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for i in range(1, 200):

    if (df_dummy['OBVTrend'][i] == 'Up') & (df_dummy['AdjCloseTrend'][i] == 'Up'):
            df_dummy['MarketTrend'][i] = 'Bullish'
    
    if (df_dummy['OBVTrend'][i] == 'Down') & (df_dummy['AdjCloseTrend'][i] == 'Down'):
            df_dummy['MarketTrend'][i] = 'Bearish'
# Out:
# /home/sauraj/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-285-408cb0e49f46> in <module>
#       2     while df_dummy['MarketTrend'][i] != 'Reversal':
#       3         if (df_dummy['OBVTrend'][i] == 'Up') & (df_dummy['AdjCloseTrend'][i] == 'Up'):
# ----> 4             df_dummy['MarketTrend'][i] = 'Bullish'
#       5
#       6         if (df_dummy['OBVTrend'][i] == 'Down') & (df_dummy['AdjCloseTrend'][i] == 'Down'):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#     936
#     937         # do the setitem
# --> 938         cacher_needs_updating = self._check_is_chained_assignment_possible()
#     939         setitem(key, value)
#     940         if cacher_needs_updating:
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py in _check_is_chained_assignment_possible(self)
#    2625             if ref is not None and ref._is_mixed_type:
#    2626                 self._check_setitem_copy(stacklevel=4, t='referant',
# -> 2627                                          force=True)
#    2628             return True
#    2629         elif self._is_copy:
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py in _check_setitem_copy(self, stacklevel, t, force)
#    2671             # the copy weakref
#    2672             try:
# -> 2673                 gc.collect(2)
#    2674                 if not gc.get_referents(self._is_copy()):
#    2675                     self._is_copy = None
#
# KeyboardInterrupt:

# %% [markdown]
# # Some basic visualization to check features

# %%
df_dummy['MACD'].plot()

# %% [markdown]
# # Detrending Data and then testing for its hypothesis

# %%
from scipy.signal import detrend
k = detrend(df_dummy['Adj Close'])

# %%
plt.plot(k)

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(df_dummy['RSI'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -2.908188
# p-value: 0.044404
# Critical Values:
# 	1%: -3.464
# 	5%: -2.876
# 	10%: -2.575

# %%
detrend_dfdummy = detrend(df_dummy)

# %%
df2 = pd.DataFrame(detrend_dfdummy)

# %%
df2 = pd.concat([df2, trend], axis=1)

# %% [markdown]
# ## Detrend Data Classification prototyping

# %%
df2.head(5)
# Out:
#               0             1             2             3             4  \
# 0 -2.247978e+07 -2.082336e+07 -1.916693e+07 -1.751051e+07  1.450535e+08
# 1 -2.852591e+07 -2.642399e+07 -2.432206e+07 -2.222013e+07  1.840669e+08
# 2 -2.486570e+07 -2.303348e+07 -2.120124e+07 -1.936902e+07  1.604489e+08
# 3 -1.441435e+07 -1.335222e+07 -1.229009e+07 -1.122796e+07  9.301019e+07
# 4 -1.371972e+07 -1.270877e+07 -1.169783e+07 -1.068688e+07  8.852799e+07
#
#               5             6             7             8             9  \
# 0 -1.419766e+07 -1.254123e+07 -1.088480e+07 -9.228650e+06 -7.572226e+06
# 1 -1.801627e+07 -1.591434e+07 -1.381241e+07 -1.171075e+07 -9.608823e+06
# 2 -1.570456e+07 -1.387233e+07 -1.204010e+07 -1.020814e+07 -8.375913e+06
# 3 -9.103699e+06 -8.041574e+06 -6.979446e+06 -5.917588e+06 -4.855457e+06
# 4 -8.664985e+06 -7.654041e+06 -6.643095e+06 -5.632420e+06 -4.621473e+06
#
#              10            11            12            13             14  \
# 0 -5.915758e+06 -4.259320e+06 -2.602920e+06 -9.465258e+05  709900.582350
# 1 -7.506847e+06 -5.404892e+06 -3.302976e+06 -1.201107e+06  900823.987606
# 2 -6.543636e+06 -4.711376e+06 -2.879149e+06 -1.046994e+06  785237.398238
# 3 -3.793273e+06 -2.731128e+06 -1.668985e+06 -6.069378e+05  455194.144036
# 4 -3.610475e+06 -2.599525e+06 -1.588560e+06 -5.776876e+05  433261.296896
#
#              15     Trend
# 0  2.366324e+06  Reversal
# 1  3.002751e+06        Up
# 2  2.617465e+06        Up
# 3  1.517321e+06        Up
# 4  1.444205e+06        Up

# %%
X = df2.drop(['Trend'], axis=1)
y = df2['Trend']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=41)

# %%
svc = SVC(kernel='rbf')
svc_crossval = cross_val_score(rf, X_train, y_train, cv=10, scoring='accuracy')

# %% [markdown]
# ## 10-Fold CV prediction accuracy after data detrending

# %%
svc_crossval
# Out:
# array([0.44444444, 0.29411765, 0.5       , 0.3125    , 0.4375    ,
#        0.625     , 0.5625    , 0.46666667, 0.53333333, 0.33333333])

# %% [markdown]
# ## PCA Decompostion Classification prototyping

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(df_dummy)
pca_df = pca.transform(df_dummy)

# %%
pca_df  = pd.DataFrame(pca_df)
pca_df[8].plot()

# %%
pca_df = pca_df.loc[~pca_df.index.duplicated(keep='first')]

# %%
pca_df = pd.concat([pca_df, trend], axis=1)

# %%
pca_df
X = pca_df.drop(['Trend'], axis=1)
y = pca_df['Trend']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2
# 171  0.027670 -0.002493  1.156480e-05      0
# 172  0.018234 -0.003231 -5.051671e-06      0
# 173  0.010241 -0.003613  5.765849e-06      0
# 174 -0.012243 -0.000166  7.337299e-06      0
# 175  0.008223 -0.003730  8.902448e-06      0
# 176 -0.011846 -0.003404  1.374594e-05      0
# 177 -0.010767 -0.001794  9.097099e-06      0
# 178  0.002392 -0.002342  6.370376e-06      0
# 179 -0.022624 -0.001313 -5.132760e-05      0
# 180 -0.013221 -0.001362  4.951176e-07      0
# 181 -0.010107 -0.000708  5.729039e-05      0
# 182 -0.006854 -0.001121 -4.615110e-06      0
# 183 -0.008249 -0.001695 -4.016680e-06      1
# 184 -0.008831 -0.000695  6.509040e-05      2
# 185 -0.005379  0.000228  7.333043e-06      2
# 186 -0.005981  0.000297  9.190208e-06      2
# 187 -0.009338  0.000061 -4.831974e-05      2
# 188 -0.007394  0.001715 -4.640099e-05      2
# 189 -0.002674  0.002227  1.298012e-05      2
# 190  0.000521  0.001057  7.768520e-06      2
# 191 -0.003086  0.000483 -5.234892e-05      2
# 192  0.002944  0.000593  7.052333e-05      1
# 193 -0.002484 -0.000397  4.533676e-06      1
# 194 -0.006595 -0.001028  4.717863e-06      0
# 195 -0.007739 -0.001887  1.312281e-05      1
# 196 -0.005851 -0.001296 -4.592441e-05      2
# 197 -0.006772 -0.000453  6.992202e-05      2
# 198  0.003263  0.001298  1.106201e-05      2
# 199  0.006108  0.000424  7.823886e-06      2
#
# [200 rows x 17 columns]

# %%
svc_crossval = cross_val_score(svc, X_train, y_train, cv=10, scoring='accuracy')
# Out:
# /home/sauraj/miniconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning:
#
# The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning:
#
# The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning:
#
# The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning:
#
# The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning:
#
# The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning:
#
# The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning:
#
# The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning:
#
# The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning:
#
# The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#
# /home/sauraj/miniconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning:
#
# The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.

# %% [markdown]
# ## 10-Fold CV after PCA decomposition (n_features were not selected here, so all the principal components were utilized for training)

# %%
svc_crossval
# Out:
# array([0.44444444, 0.44444444, 0.44444444, 0.5       , 0.46666667,
#        0.46666667, 0.46666667, 0.46666667, 0.46666667, 0.46666667])

# %% [markdown]
# # Min-Max scaling
