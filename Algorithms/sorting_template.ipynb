# %%
from __future__ import print_function, division
import numpy as np
import timeit

# %%
from collections import deque

def mergesort(lst, low, high):
    
    #Mergesort using divide and conquer approach to solving the sequential sorting of a given list with float
    if all(isinstance(n, float) for n in lst) is False: 
        raise ValueError('The algorithm is only meant to compare float values!. Please enter a list with float values')
        
#     low = 0 
#     high = len(lst)
    
    if low < high:
        middle = (low+high)//2
        mergesort(lst,low,middle)
        mergesort(lst,middle+1,high)
        
        return merge(left, right)

# %%
# from collections import deque
import random 
import doctest

def mergesort(lst):
    
    #Mergesort using divide and conquer approach to solving the sequential sorting of a given list with float
    # if all(isinstance(n, float) for n in lst) is False: 
    #     raise ValueError('The algorithm is only meant to compare float values!. Please enter a list with float values')
        
#     low = 0 
#     high = len(lst)
    
    if len(lst) > 1:
        split_point = int(len(lst)//2)
        part_1 = lst[:split_point]
        part_2 = lst[split_point:]

        mergesort(part_1)
        mergesort(part_2)
        

        i = j = k = 0

        while i < len(part_1) and j < len(part_2):
            if part_1[i] < part_2[j]:
                lst[k] = part_1[i]
                
                i += 1
            else:
                lst[k] = part_2[j]
                j += 1
            
            k += 1

            #For the remaining values 
        while i < len(part_1):
                lst[k] = part_1[i]
                i += 1
                k += 1

        while j < len(part_2):
                lst[k]  = part_2[j]
                j += 1
                k += 1
                
        return lst

# %%
import random

times = [] #Stores the time for each run 
for i in range(100):
    random_nums = [random.random() for i in range(10)] #Generates random numbers of length "n"
    run = timeit.timeit(
        '''
        def mergesort(ll):
            ll = random_nums

            if len(ll) > 1:
                split_point = int(len(ll)//2)
                part_1 = ll[:split_point]
                part_2 = ll[split_point:]

                mergesort(part_1)
                mergesort(part_2)


                i = j = k = 0

                while i < len(part_1) and j < len(part_2):
                    if part_1[i] < part_2[j]:
                        ll[k] = part_1[i]

                        i += 1
                    else:
                        ll[k] = part_2[j]
                        j += 1

                    k += 1

                    #For the remaining values 
                while i < len(part_1):
                        ll[k] = part_1[i]
                        i += 1
                        k += 1

                while j < len(part_2):
                        ll[k]  = part_2[j]
                        j += 1
                        k += 1



            return ll

        ''', number=1)
    time.append(run)
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\Sauraj (Work mode)\Miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-520-8283f1514abf>", line 48, in <module>
#     ''', number=1)
#
#   File "C:\Users\Sauraj (Work mode)\Miniconda3\lib\timeit.py", line 232, in timeit
#     return Timer(stmt, setup, timer, globals).timeit(number)
#
#   File "C:\Users\Sauraj (Work mode)\Miniconda3\lib\timeit.py", line 121, in __init__
#     compile(stmtprefix + stmt, dummy_src_name, "exec")
#
#   File "<timeit-src>", line 3
#     def mergesort(ll):
#     ^
# IndentationError: unexpected indent

# %%
from __future__ import print_function, division
num_list = [random.random() for i in range(5000)]

print(mergesort(num_list))
doctest.testmod()
# Out:
# [0.0001721076086430573, 0.0006283168591627586, 0.0014422645626951391, 0.00144754113424983, 0.0015991618620901926, 0.002154141436905843, 0.0024433422517925463, 0.0027533857139014906, 0.0032820171909427875, 0.003296575090581455, 0.0032986198108129194, 0.0033226714360378162, 0.003488675877228453, 0.003576095923821354, 0.0035923307526272152, 0.0036247083496848687, 0.0037212210149637492, 0.0037739293375534944, 0.003826367730904723, 0.003972328046430329, 0.004349712115615523, 0.005470645580127664, 0.005594772446731455, 0.005640691506852535, 0.006076487926000018, 0.006212878251665277, 0.006271395063228269, 0.006322749462789656, 0.006402802016610143, 0.006577467527685843, 0.006616699254993308, 0.007438872827741028, 0.007621079893913474, 0.00789921161051177, 0.00830339824712023, 0.008306935714751718, 0.008412982181106532, 0.00848431453184495, 0.0086086645751422, 0.008732551575472924, 0.009266999300779788, 0.009297052697311736, 0.009679690005165997, 0.009967314011044559, 0.010461543879684343, 
# ...

# %%
def mergesort(ll):
    '''Sorts list ll according to the mergesort algorithm.
       
       Comparisons are made according to the default "<" and "=" on floats.
       
       >>> a = [7, 3, 2]
       >>> mergesort(a)
       [2, 3, 7]
       
    '''
    # add your code here and return with
    # something like `return sortedlist`
    
    if len(ll) > 1:
        split_point = int(len(ll)//2)
        part_1 = ll[:split_point]
        part_2 = ll[split_point:]

        mergesort(part_1)
        mergesort(part_2)


        i = j = k = 0

        while i < len(part_1) and j < len(part_2):
            if part_1[i] < part_2[j]:
                ll[k] = part_1[i]
                
                i += 1
            else:
                ll[k] = part_2[j]
                j += 1
            
            k += 1

            #For the remaining values 
        while i < len(part_1):
                ll[k] = part_1[i]
                i += 1
                k += 1

        while j < len(part_2):
                ll[k]  = part_2[j]
                j += 1
                k += 1
                

    
    return ll
    

import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=2)

# %%
import timeit 
timeit.timeit(
'''
import random
num_list = [random.random() for i in range(10000)]

def mergesort(ll):


    if len(ll) > 1:
        split_point = int(len(ll)//2)
        part_1 = ll[:split_point]
        part_2 = ll[split_point:]

        mergesort(part_1)
        mergesort(part_2)


        i = j = k = 0

        while i < len(part_1) and j < len(part_2):
            if part_1[i] < part_2[j]:
                ll[k] = part_1[i]

                i += 1
            else:
                ll[k] = part_2[j]
                j += 1

            k += 1

            #For the remaining values 
        while i < len(part_1):
                ll[k] = part_1[i]
                i += 1
                k += 1

        while j < len(part_2):
                ll[k]  = part_2[j]
                j += 1
                k += 1



    return ll

mergesort(num_list)
''', number=100)
# mergesort()
# Out:
# 5.299339600000167

# %%
times_ms = [0.0019033999997191131, 0.03517899999860674, 0.4086554999994405, 5.299339600000167]
times_ts =

# %%
#TimSORT implementation 
timeit.timeit(
'''
import random
num_list = [random.random() for i in range(10000)]


sorted(num_list)
''', number=100)
# Out:
# 0.24523670000053244

# %%
times_ts = [0.00024120000125549268, 0.0019632999992609257, 0.028340400000161026, 0.24523670000053244]

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot

plt.figure(dpi=500)
values = [10, 100, 1000, 10000]
width = 0.4


y_range = np.arange(len(values))
plt.bar(y_range, times, width, edgecolor='black', label='MergeSort')
plt.bar(y_range+width, times_ts,width, edgecolor='black', label='TimSort')
plt.xticks(y_range, values)
plt.xlabel("Number of elements in each list")
plt.ylabel("Time taken ($s$)")
plt.legend()
plt.title("MergeSort vs TimSort")
plt.savefig('maria.png', dpi=1000)
